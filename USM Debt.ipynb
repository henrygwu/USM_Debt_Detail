# %%
#Import pandas for data manipulation
import pandas as pd

# %%
#maximize how much will be displayed
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)
pd.set_option('display.max_colwidth', None)

# %%
#declare variables for file location of where the Excel file is stored to import and destination of where to export Excel
file_location = r'C:\Users\User\Documents\Python\FY21DebtSummary.xlsx'
destination_location = r'C:\Users\User\Documents\Python\Test2.xlsx'
destination_location2 = r'C:\Users\User\Documents\Python\Test1.xlsx'

# %%
#test import of excel and creating blank column for Bond Series
df = pd.read_excel(file_location, sheet_name='21B')
df['Series'] = ''
df
# Out:
#     University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0                   2021 Series B        NaN        NaN        NaN
# 1               FYE June 30, 2021        NaN        NaN        NaN
# 2                             NaN        NaN        NaN        NaN
# 3                             NaN        NaN        NaN        NaN
# 4                             NaN        NaN   Academic       Debt
# ..                            ...        ...        ...        ...
# 172               Total  Projects        NaN        NaN          0
# 173                           NaN        NaN        NaN        NaN
# 174                           NaN        NaN        NaN        NaN
# 175                           NaN        NaN        NaN        NaN
# 176                           NaN        NaN        NaN        NaN
#
#      Unnamed: 4  Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 0           NaN         NaN        NaN        NaN        NaN        NaN
# ...

# %%
#Designate the column headers for the data and put them in a list
column_list = ['Project',
               'Institution',
               'Academic/Auxiliary',
               'Debt_Old',
               'Allocation_of_debt',
               'FY_2021Principal_Paid',
               'Debt_New',
               'FY_2021InterestPaid',
               'Accrued_InterestPayable_Old',
               'Accrued_InterestPayable_New',
                'Allocation_of_Unamort.Premium/(Dis)_Old',
               'Allocation_of_Premium/(Dis)',
               'FY_2021AmortizationofPremium/(Dis)',
               'Allocation_of_Unamort.Premium/(Dis)_New',
               'Allocation_of_Unamort.Loss/(Gain)_Old',
               'Allocationof_Loss/(Gain)',
               'FY_2021AmortizationofLoss/(Gain)',
               'Allocation_of_Unamort.Loss/(Gain)_New',
               'FY_2021InterestExpense',
               'FY_2021CapitalizedInterest',
               'Series'
]

# %%
#set the columns of the data frame equal to the column list headers
df.columns = column_list

# %%
#test the data frame to see if the headers are there
df
# Out:
#                Project Institution Academic/Auxiliary Debt_Old  \
# 0        2021 Series B         NaN                NaN      NaN
# 1    FYE June 30, 2021         NaN                NaN      NaN
# 2                  NaN         NaN                NaN      NaN
# 3                  NaN         NaN                NaN      NaN
# 4                  NaN         NaN           Academic     Debt
# ..                 ...         ...                ...      ...
# 172    Total  Projects         NaN                NaN        0
# 173                NaN         NaN                NaN      NaN
# 174                NaN         NaN                NaN      NaN
# 175                NaN         NaN                NaN      NaN
# 176                NaN         NaN                NaN      NaN
#
#     Allocation_of_debt FY_2021Principal_Paid   Debt_New FY_2021InterestPaid  \
# 0                  NaN                   NaN        NaN                 NaN
# ...

# %%
#Test filtering data frame by Towson University
df_21B = df[(df['Institution'] == 'TU')]

#~ means not like !=
"""dfg
dfsdfgsdf
"""
df_21B = df_21B[~df_21B['Project'].isnull()]
df_21B['Series'] = '21B'
df_21B
# Out:
#                                        Project Institution Academic/Auxiliary  \
# 26                 New College of Liberal Arts          TU           Academic
# 27                          Facilities Renewal          TU           Academic
# 46                               Burdick Renov          TU          Auxiliary
# 47                       Residence Halls Renov          TU          Auxiliary
# 48           Student Housing-West Village PHII          TU          Auxiliary
# 49                               Towson Center          TU          Auxiliary
# 50              West Village Parking Structure          TU          Auxiliary
# 51                 West Village Dining Commons          TU          Auxiliary
# 52   West Village Infrastructure & Site Improv          TU          Auxiliary
# 82                 New College of Liberal Arts          TU           Academic
# 83                          Facilities Renewal          TU           Academic
# ...

# %%
#Pull data from tab 12AB and set equal to dataframe df_12AB. Create Series column showing the Bond Series name
df_12AB = pd.read_excel(file_location, sheet_name='12AB')
df_12AB['Series'] = '12AB'
df_12AB
# Out:
#      University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    2012 Series A&B Revenue Bonds        NaN        NaN        NaN
# 1                FYE June 30, 2021        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4                              NaN        NaN        NaN  Long-term
# ..                             ...        ...        ...        ...
# 237                           UMBC        NaN        NaN     458982
# 238                          UMCES        NaN        NaN      32443
# 239                     USM Office        NaN        NaN    3057607
# 240                            NaN        NaN        NaN        NaN
# 241                         Totals        NaN        NaN   15490002
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  Unnamed: 8 Unnamed: 9  \
# 0          NaN        NaN        NaN        NaN         NaN        NaN
# ...

# %%
#Rearrange column to fit the same order as other tabs in the spreadsheet
df_12AB8 = df_12AB.pop("Unnamed: 8")
df_12AB.insert(10,'Allocation_of_Unamort.Premium/(Dis)_Old',df_12AB8)

# %%
df_12AB
# Out:
#      University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    2012 Series A&B Revenue Bonds        NaN        NaN        NaN
# 1                FYE June 30, 2021        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4                              NaN        NaN        NaN  Long-term
# ..                             ...        ...        ...        ...
# 237                           UMBC        NaN        NaN     458982
# 238                          UMCES        NaN        NaN      32443
# 239                     USM Office        NaN        NaN    3057607
# 240                            NaN        NaN        NaN        NaN
# 241                         Totals        NaN        NaN   15490002
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 9 Unnamed: 10  \
# 0          NaN        NaN        NaN        NaN        NaN         NaN
# ...

# %%
df_12AB9 = df_12AB.pop("Unnamed: 9")
df_12AB.insert(10,'Allocation_of_Premium/(Dis)',df_12AB9)

# %%
df_12AB
# Out:
#      University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    2012 Series A&B Revenue Bonds        NaN        NaN        NaN
# 1                FYE June 30, 2021        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4                              NaN        NaN        NaN  Long-term
# ..                             ...        ...        ...        ...
# 237                           UMBC        NaN        NaN     458982
# 238                          UMCES        NaN        NaN      32443
# 239                     USM Office        NaN        NaN    3057607
# 240                            NaN        NaN        NaN        NaN
# 241                         Totals        NaN        NaN   15490002
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 10  \
# 0          NaN        NaN        NaN        NaN         NaN
# ...

# %%
df_12AB10 = df_12AB.pop("Unnamed: 10")
df_12AB.insert(10,'FY_2021AmortizationofPremium/(Dis)',df_12AB10)

# %%
df_12AB
# Out:
#      University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    2012 Series A&B Revenue Bonds        NaN        NaN        NaN
# 1                FYE June 30, 2021        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4                              NaN        NaN        NaN  Long-term
# ..                             ...        ...        ...        ...
# 237                           UMBC        NaN        NaN     458982
# 238                          UMCES        NaN        NaN      32443
# 239                     USM Office        NaN        NaN    3057607
# 240                            NaN        NaN        NaN        NaN
# 241                         Totals        NaN        NaN   15490002
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7  \
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# ...

# %%
df_12AB16 = df_12AB.pop("Unnamed: 16")
df_12AB.insert(8,'Accrued_InterestPayable_Old',df_12AB16)

# %%
df_12AB
# Out:
#      University System of Maryland Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 0    2012 Series A&B Revenue Bonds        NaN        NaN        NaN
# 1                FYE June 30, 2021        NaN        NaN        NaN
# 2                              NaN        NaN        NaN        NaN
# 3                              NaN        NaN        NaN        NaN
# 4                              NaN        NaN        NaN  Long-term
# ..                             ...        ...        ...        ...
# 237                           UMBC        NaN        NaN     458982
# 238                          UMCES        NaN        NaN      32443
# 239                     USM Office        NaN        NaN    3057607
# 240                            NaN        NaN        NaN        NaN
# 241                         Totals        NaN        NaN   15490002
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Accrued_InterestPayable_Old  \
# ...

# %%
#Rearrangle columns and bring over headers
df_12AB17 = df_12AB.pop("Unnamed: 17")
df_12AB.insert(9,'Accrued_InterestPayable_New',df_12AB17)
df_12AB.columns = column_list

# %%
df_12AB
# Out:
#                            Project Institution Academic/Auxiliary   Debt_Old  \
# 0    2012 Series A&B Revenue Bonds         NaN                NaN        NaN
# 1                FYE June 30, 2021         NaN                NaN        NaN
# 2                              NaN         NaN                NaN        NaN
# 3                              NaN         NaN                NaN        NaN
# 4                              NaN         NaN                NaN  Long-term
# ..                             ...         ...                ...        ...
# 237                           UMBC         NaN                NaN     458982
# 238                          UMCES         NaN                NaN      32443
# 239                     USM Office         NaN                NaN    3057607
# 240                            NaN         NaN                NaN        NaN
# 241                         Totals         NaN                NaN   15490002
#
# ...

# %%
#import data from tab 21A
df_21A = pd.read_excel(file_location, sheet_name='21A')

# %%
#Create column for Series number 21A
df_21A['Series'] = '21A'

# %%
#Rearrange columns and also bring over the headers
df_21A1 = df_21A.pop("University System of Maryland")
df_21A.insert(0,'Project',df_21A1)
df_21A.columns = column_list

# %%
df_21A
# Out:
#                          Project Institution Academic/Auxiliary Debt_Old  \
# 0    2021 Series A Revenue Bonds         NaN                NaN      NaN
# 1              FYE June 30, 2021         NaN                NaN      NaN
# 2                            NaN         NaN                NaN      NaN
# 3                            NaN         NaN                NaN      NaN
# 4                            NaN         NaN                NaN      NaN
# ..                           ...         ...                ...      ...
# 380                         UMBC         NaN                NaN        0
# 381                        UMCES         NaN                NaN        0
# 382                   USM Office         NaN                NaN        0
# 383                          NaN         NaN                NaN      NaN
# 384                       Totals         NaN                NaN        0
#
#     Allocation_of_debt FY_2021Principal_Paid   Debt_New FY_2021InterestPaid  \
# ...

# %%
#import data from tab 16B
df_16B = pd.read_excel(file_location, sheet_name='16B')

# %%
#create column for Series number with 16B value
df_16B['Series'] = '16B'

# %%
df_16B
# Out:
#                                                               University System of Maryland  \
# 0    Allocation of accrued interest payable, unamortized discount/Premium  - 2016 Series B
# 1                                                                       As of FYE 6/30/2021
# 2                                                                                       NaN
# 3                                                                                       NaN
# 4                                                                                       NaN
# ..                                                                                      ...
# 207                                                                                     NaN
# 208                                                                                     NaN
# 209                                                                                     NaN
# ...

# %%
#rearrange columns
df_16B1 = df_16B.pop("Unnamed: 1")
df_16B.insert(0,'Project',df_16B1)
df_16B.columns = column_list

# %%
df_16B
# Out:
#        Project  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 207       USMH
# 208        NaN
# 209     Totals
# 210        NaN
# 211        NaN
#
#                                                                                 Institution  \
# 0    Allocation of accrued interest payable, unamortized discount/Premium  - 2016 Series B
# 1                                                                       As of FYE 6/30/2021
# 2                                                                                       NaN
# 3                                                                                       NaN
# 4                                                                                       NaN
# ..                                                                                      ...
# 207                                                                                     NaN
# ...

# %%
#import data from tab 15A
df_15A = pd.read_excel(file_location, sheet_name='15A')

# %%
#create column for series number 15A
df_15A['Series'] = '15A'

# %%
#rearrange columns and bring over column headers
df_15A1 = df_15A.pop("Unnamed: 1")
df_15A.insert(0,'Project',df_15A1)
df_15A.columns = column_list

# %%
df_15A
# Out:
#        Project  \
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# ..         ...
# 274       UMBC
# 275       CEES
# 276       USMH
# 277        NaN
# 278     Totals
#
#                                                                        Institution  \
# 0    Allocation of accrued interest payable, unamortized Premium  - 2015 Series A
# 1                                                              As of FYE 6/30/2021
# 2                                                                              NaN
# 3                                                                              NaN
# 4                                                                              NaN
# ..                                                                             ...
# 274                                                                            NaN
# 275                                                                            NaN
# ...

# %%
#import data from tab 09D
df_09D = pd.read_excel(file_location, sheet_name='09D')

# %%
#create column for series name 09D
df_09D['Series'] = '09D'

# %%
df_09D
# Out:
#     Unnamed: 0 University System of Maryland Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0          NaN   2009 Series D Revenue Bonds        NaN        NaN        NaN
# 1          NaN             FYE June 30, 2021        NaN        NaN        NaN
# 2          NaN                           NaN        NaN        NaN        NaN
# 3          NaN                           NaN        NaN        NaN        NaN
# 4          NaN                           NaN        NaN        NaN        NaN
# ..         ...                           ...        ...        ...        ...
# 257        NaN                          UMBC        NaN     183295      93463
# 258        NaN                         UMCES        NaN        357        181
# 259        NaN                    USM Office        NaN      74175      37824
# 260        NaN                           NaN        NaN        NaN        NaN
# 261        NaN                        Totals        NaN    4040007    2060018
#
# ...

# %%
#rearrange columns
df_09D1 = df_09D.pop("University System of Maryland")
df_09D.insert(0,'Project',df_09D1)

# %%
df_09D
# Out:
#                          Project Unnamed: 0 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    2009 Series D Revenue Bonds        NaN        NaN        NaN        NaN
# 1              FYE June 30, 2021        NaN        NaN        NaN        NaN
# 2                            NaN        NaN        NaN        NaN        NaN
# 3                            NaN        NaN        NaN        NaN        NaN
# 4                            NaN        NaN        NaN        NaN        NaN
# ..                           ...        ...        ...        ...        ...
# 257                         UMBC        NaN        NaN     183295      93463
# 258                        UMCES        NaN        NaN        357        181
# 259                   USM Office        NaN        NaN      74175      37824
# 260                          NaN        NaN        NaN        NaN        NaN
# 261                       Totals        NaN        NaN    4040007    2060018
#
# ...

# %%
#delete column not in use
df_09D.drop('Unnamed: 0', axis=1)
# Out:
#                          Project Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 0    2009 Series D Revenue Bonds        NaN        NaN        NaN        NaN
# 1              FYE June 30, 2021        NaN        NaN        NaN        NaN
# 2                            NaN        NaN        NaN        NaN        NaN
# 3                            NaN        NaN        NaN        NaN        NaN
# 4                            NaN        NaN        NaN        NaN        NaN
# ..                           ...        ...        ...        ...        ...
# 257                         UMBC        NaN     183295      93463      89832
# 258                        UMCES        NaN        357        181        176
# 259                   USM Office        NaN      74175      37824      36351
# 260                          NaN        NaN        NaN        NaN        NaN
# 261                       Totals        NaN    4040007    2060018    1979989
#
# ...

# %%
#split column by hypthen to separate institution from project name
df_09D_split = df_09D["Project"].str.split("-",expand=True)
df_09D_split
# Out:
#                                0     1
# 0    2009 Series D Revenue Bonds  None
# 1              FYE June 30, 2021  None
# 2                            NaN   NaN
# 3                            NaN   NaN
# 4                            NaN   NaN
# ..                           ...   ...
# 257                         UMBC  None
# 258                        UMCES  None
# 259                   USM Office  None
# 260                          NaN   NaN
# 261                       Totals  None
#
# [262 rows x 2 columns]

# %%
#combine data frame from split with previous data frame to get all the data
df_09D = pd.concat([df_09D,df_09D_split], axis=1)

# %%
df_09D
# Out:
#                          Project Unnamed: 0 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0    2009 Series D Revenue Bonds        NaN        NaN        NaN        NaN
# 1              FYE June 30, 2021        NaN        NaN        NaN        NaN
# 2                            NaN        NaN        NaN        NaN        NaN
# 3                            NaN        NaN        NaN        NaN        NaN
# 4                            NaN        NaN        NaN        NaN        NaN
# ..                           ...        ...        ...        ...        ...
# 257                         UMBC        NaN        NaN     183295      93463
# 258                        UMCES        NaN        NaN        357        181
# 259                   USM Office        NaN        NaN      74175      37824
# 260                          NaN        NaN        NaN        NaN        NaN
# 261                       Totals        NaN        NaN    4040007    2060018
#
# ...

# %%
#reassign column headers
df_09D['Project'] = df_09D[1]
df_09D['Unnamed: 0'] = df_09D[0]

# %%
df_09D
# Out:
#     Project                   Unnamed: 0 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0      None  2009 Series D Revenue Bonds        NaN        NaN        NaN
# 1      None            FYE June 30, 2021        NaN        NaN        NaN
# 2       NaN                          NaN        NaN        NaN        NaN
# 3       NaN                          NaN        NaN        NaN        NaN
# 4       NaN                          NaN        NaN        NaN        NaN
# ..      ...                          ...        ...        ...        ...
# 257    None                         UMBC        NaN     183295      93463
# 258    None                        UMCES        NaN        357        181
# 259    None                   USM Office        NaN      74175      37824
# 260     NaN                          NaN        NaN        NaN        NaN
# 261    None                       Totals        NaN    4040007    2060018
#
#     Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# ...

# %%
#delete columns no longer in use since this is a duplicate
df_09D = df_09D.drop([0,1], axis=1)

# %%
df_09D.columns = column_list

# %%
df_09D
# Out:
#     Project                  Institution Academic/Auxiliary Debt_Old  \
# 0      None  2009 Series D Revenue Bonds                NaN      NaN
# 1      None            FYE June 30, 2021                NaN      NaN
# 2       NaN                          NaN                NaN      NaN
# 3       NaN                          NaN                NaN      NaN
# 4       NaN                          NaN                NaN      NaN
# ..      ...                          ...                ...      ...
# 257    None                         UMBC                NaN   183295
# 258    None                        UMCES                NaN      357
# 259    None                   USM Office                NaN    74175
# 260     NaN                          NaN                NaN      NaN
# 261    None                       Totals                NaN  4040007
#
#     Allocation_of_debt FY_2021Principal_Paid Debt_New FY_2021InterestPaid  \
# ...

# %%
#create a list of tabs that need to have four columns inserted to match structure of other tabs
add_columns = ['19A','18A','17A','16A','14A','12C','11A','10DE','10AB']

# %%
new_df = []

# %%
#function to pass in tabs and have four columns inserted and add series name
def adding_columns(add_columns):
    #loading the excel with each tab need columns added
    df_columns = pd.read_excel(file_location, add_columns)
    df_columns.insert(14,'Allocation_of_Unamort.Loss/(Gain)_Old','')
    df_columns.insert(15,'Allocationof_Loss/(Gain)','')
    df_columns.insert(16,'FY_2021AmortizationofLoss/(Gain)','')
    df_columns.insert(17,'Allocation_of_Unamort.Loss/(Gain)_New','')
    df_columns['Series'] = add_columns
    df_columns.columns = column_list
    return df_columns

# %%
#test and pass in tab 19A to see four columns inserted
df_19A = adding_columns('19A')

# %%
df_19A
# Out:
#                Project Institution Academic/Auxiliary Debt_Old  \
# 0        2019 Series A         NaN                NaN      NaN
# 1    FYE June 30, 2021         NaN                NaN      NaN
# 2                  NaN         NaN                NaN      NaN
# 3                  NaN         NaN                NaN      NaN
# 4                  NaN         NaN           Academic     Debt
# ..                 ...         ...                ...      ...
# 108                NaN         NaN                NaN      NaN
# 109                NaN         NaN                NaN      NaN
# 110                NaN         NaN                NaN      NaN
# 111                NaN         NaN                NaN      NaN
# 112                NaN         NaN                NaN        0
#
#     Allocation_of_debt FY_2021Principal_Paid Debt_New FY_2021InterestPaid  \
# 0                  NaN                   NaN      NaN                 NaN
# ...

# %%
#call function to pass in the other tabs to have four columns inserted
df_18A = adding_columns('18A')
df_17A = adding_columns('17A')
df_16A = adding_columns('16A')
df_14A = adding_columns('14A')
df_12C = adding_columns('12C')
df_11A = adding_columns('11A')
df_10DE = adding_columns('10DE')
df_10AB = adding_columns('10AB')

# %%
df_multiple = [df_21B, df_12AB, df_21A, df_16B, df_15A, df_09D, df_19A, df_18A, df_17A, df_16A, df_14A, df_12C, df_11A, df_10DE, df_10AB]

# %%
add_tabs = ['10C','11B','12D','17B','19B','19C']

# %%
#function to pass in tabs to have series column added
def import_tabs(add_tabs):
    #loading the excel with each tab need columns added
    df_tabs = pd.read_excel(file_location, add_tabs)
    df_tabs['Series'] = add_tabs
    df_tabs.columns = column_list
    return df_tabs

# %%
df_total = pd.concat(df_multiple)

# %%
df_total
# Out:
#                                Project Institution Academic/Auxiliary  \
# 26         New College of Liberal Arts          TU           Academic
# 27                  Facilities Renewal          TU           Academic
# 46                       Burdick Renov          TU          Auxiliary
# 47               Residence Halls Renov          TU          Auxiliary
# 48   Student Housing-West Village PHII          TU          Auxiliary
# ..                                 ...         ...                ...
# 120                                NaN        UMBC                NaN
# 121                                NaN       UMCES                NaN
# 122                                NaN  USM Office                NaN
# 123                                NaN         NaN                NaN
# 124                    Total  Projects         NaN                NaN
#
#     Debt_Old Allocation_of_debt FY_2021Principal_Paid Debt_New  \
# ...

# %%
#call function to have series name added to the end
df_10C = import_tabs('10C')
df_11B = import_tabs('11B')
df_12D = import_tabs('12D')
df_17B = import_tabs('17B')
df_19B = import_tabs('19B')
df_19C = import_tabs('19C')

# %%
df_multiple2 = [df_10C, df_11B, df_12D, df_17B, df_19B, df_19C]

# %%
#combine all data frame tabs together in a list
df_final_multiple = [df_21B, df_12AB, df_21A, df_16B, df_15A, df_09D, df_19A, df_18A, df_17A, df_16A, df_14A, df_12C, df_11A, df_10DE, df_10AB, df_10C, df_11B, df_12D, df_17B, df_19B, df_19C]

# %%
#use concat to combine the data
df_final_total = pd.concat(df_final_multiple)

# %%
#export All institutions Excel to local computer
df_final_total.to_excel(destination_location, index = False)

# %%
df_final_TU = df_final_total[~df_final_total.Project.isnull()]

# %%
df_final_TU
# Out:
#                                Project Institution Academic/Auxiliary  \
# 26         New College of Liberal Arts          TU           Academic
# 27                  Facilities Renewal          TU           Academic
# 46                       Burdick Renov          TU          Auxiliary
# 47               Residence Halls Renov          TU          Auxiliary
# 48   Student Housing-West Village PHII          TU          Auxiliary
# ..                                 ...         ...                ...
# 151            Total Academic Projects         NaN                NaN
# 154                 Auxiliary Projects         NaN                NaN
# 170           Total Auxiliary Projects         NaN                NaN
# 173                     Total Projects         NaN                NaN
# 189                    Total  Projects         NaN                NaN
#
#       Debt_Old Allocation_of_debt FY_2021Principal_Paid   Debt_New  \
# ...

# %%
df_final_TU = df_final_TU[(df_final_TU['Institution'] == 'TU') | (df_final_TU['Institution'] == 'TU ')]

# %%
df_final_TU
# Out:
#                                        Project Institution Academic/Auxiliary  \
# 26                 New College of Liberal Arts          TU           Academic
# 27                          Facilities Renewal          TU           Academic
# 46                               Burdick Renov          TU          Auxiliary
# 47                       Residence Halls Renov          TU          Auxiliary
# 48           Student Housing-West Village PHII          TU          Auxiliary
# ..                                         ...         ...                ...
# 121                Residence Halls Renovations          TU          Auxiliary
# 122                        Towson Center Arena          TU          Auxiliary
# 123                West Village Dining Commons          TU          Auxiliary
# 124             West Village Parking Structure          TU          Auxiliary
# 125  West Village Infrastructure & Site Improv          TU          Auxiliary
#
# ...

# %%
#Export only TU Institution Excel to local computer
df_final_TU.to_excel(destination_location2, index = False)
